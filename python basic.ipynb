# %%
print("hello word")
# Out:
# hello word

# %%
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
sum=num1+num2
print("Sum is=",sum)
# Out:
# Enter first number 10
# Enter second number 50
# Sum is= 60

# %%
A = int(input("Enter a number: "))

if A % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number:  12
# Number is even

# %%
num=[10,12,20,2,35]
largest=max(num)
print("The largest is",max(num))
# Out:
# The largest is 35

# %%
P = float(input("Enter Principal amount: "))
R = float(input("Enter Rate of interest (%): "))
T = float(input("Enter Time (in years): "))

SI = (P * R * T) / 100
print("Simple Interest =", SI)
# Out:
# Enter Principal amount:  2000
# Enter Rate of interest (%):  5
# Enter Time (in years):  10
# Simple Interest = 1000.0

# %%
n1=100
n2=200
print("sum is,subtraction is:",n1+n2,n1-n2)
print("Multi is:",n1*n2)
print("Dive is :",n1/n2)
print(n1//n2)
# Out:
# sum is,subtraction is: 300 -100
# Multi is: 20000
# Dive is : 0.5
# 0

# %%
a = int(input("Enter a"))
b= int(input("Enter b"))
print(a+b)
# Out:
# Enter a 10
# Enter b 5646
# 5656

# %%
a=10
b=50
print("values before swaping",a ,b)
temp=a
a=b
b=temp
print("values after swaping",a ,b)
# Out:
# values before swaping 10 50
# values after swaping 50 10

# %%
a=2326415
b=354986451
print("values before swaping",a ,b)
a,b=b,a
print("values after swaping",a ,b)
# Out:
# values before swaping 2326415 354986451
# values after swaping 354986451 2326415

# %%
a=int(input("Enter a number:"))
print("Square of a number is:",a*a)
# Out:
# Enter a number: 4
# Square of a number is: 16

# %%
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    
    print("Choose your operation:")
    print("+ : Add")
    print("- : Sub")
    print("* : Mult")
    print("/ : Div")
    c = input("Enter your choice: ")
    
    if c == "+":
        print("Sum is:", a + b)
    elif c == "-":
        print("Sub is:", a - b)
    elif c == "*":
        print("Multi is:", a * b)
    elif c == "/":
        print("Div is:", a / b)
    else:
        print("Invalid choice")
# Out:
# Enter first number:  10
# Enter second number:  6
# Choose your operation:
# + : Add
# - : Sub
# * : Mult
# / : Div
# Enter your choice:  +
# Sum is: 16

# %%
a=10
b=50
c=90
print("Average of 3 numbers is:",(a+b+c)/3)
# Out:
# Average of 3 numbers is: 50.0

# %%
deg=float(input("Enter the temperatuer in degree"))
far=(deg * 9/5) + 32
print("Temp in faranite:",far)
# Out:
# Enter the temperatuer in degree 25
# Temp in faranite: 77.0

# %%
#to check weather +ve,-ve , or zero
a=int(input("Enter a number:"))
if a == 0:
    print("The number is zero")
elif a > 0:
    print("The number is positive")
else:
    print("The number is negetive")
# Out:
# Enter a number: -154
# The number is negetive

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0):
    print("It is a leap year")
else:
    print("It is not a leap year")
# Out:
# Enter a year:  2000
# It is a leap year

# %%
ch = input("enter a character")
if ch.lower() in ['a', 'e', 'i', 'o', 'u']:  
    print("The character is vowel")
else:
    print("The character is consonant")
# Out:
# enter a character l
# The character is consonant

# %%
marks = int(input("Enter your marks: "))
if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
elif marks >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter your marks:  566
# Grade: A

# %%
#number is divisible by both 5 and 11
A= int(input("Enter a number: "))
if A % 5 == 0 and A % 11 == 0:
    print("The number is divisible by both 5 and 11")
elif A % 5 == 0:
    print("The number is divisible by 5")
elif A % 11 == 0:
    print("The number is divisible only by 11")
elif A % 5 != 0 and A % 11 != 0:
    print("The number is not divisible by either 5 or 11")
# Out:
# Enter a number:  126
# The number is not divisible by either 5 or 11

# %%
ch = input("Enter a character: ")
if ch.isalpha():
    print("The character is an alphabet")
elif ch.isdigit():
    print("The character is a digit")
else:
    print("The character is a special character")
# Out:
# Enter a character:  4
# The character is a digit

# %%
n = int(input("Enter a number: "))
factorial = 1
if n < 0:
    print("Factorial does not exist for negative numbers")
elif n == 0:
    print("The factorial of 0 is 1")
else:
    for i in range(1, n + 1):
        factorial *= i
    print("The factorial of", n, "is", factorial)
# Out:
# Enter a number:  12
# The factorial of 12 is 479001600

# %%
#check whether a number is divisible by 3 or not.
n=int(input("enter a number:"))
if n %3 == 0:
    print("the number is divisible by 3")
else:
    print("the number is not divisible by 3")
# Out:
# enter a number: 4
# the number is not divisible by 3

# %%
P = float(input("Enter Principal amount: "))
R = float(input("Enter Rate of interest (%): "))
T = float(input("Enter Time (in years): "))

SI = (P * R * T) / 100
print("Simple Interest =", SI)
# Out:
# Enter Principal amount:  4000
# Enter Rate of interest (%):  5
# Enter Time (in years):  2
# Simple Interest = 400.0
